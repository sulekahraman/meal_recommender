# %%
import pandas as pd
import re
import ast

from string import digits
from string import punctuation

# %%
recipes = pd.read_csv('recipe_final/recipe_final.csv')

# %%
common = {"tablespoons", "tablespoon", "teaspoon", "teaspoons", "tbsp", "tsp", "cup", "cups", "ounces",
          "lb", "lbs", "lbs", "box", "pound", "pounds", "whole", "gram", "grams", "g", "ml",
          "oz", "oz.", "parts", "part", "", "/", "-", "the", "and", "into", "cut","fresh", "minced", "chopped", "finely", "or",
          "for", "of", "to","salt", "pepper", "your", "taste", "etc", "sliced", "big", "small", "large", "intact", "flakes"}

remove_digits = str.maketrans('', '', digits)
remove_punctuation = str.maketrans('', '', punctuation)

def preprocess(cell):
    ingredients = ast.literal_eval(cell)
    long_ing_string = ' '.join(ingredients).lower()
    cleaned_ing_set = set(long_ing_string.translate(remove_digits).translate(remove_punctuation).split(" "))
    cleaned_ing_set.difference_update(common)
    return '+'.join(cleaned_ing_set)

subset = recipes.head()
subset['processed_ing'] = subset.apply(lambda x: preprocess(x.ingredient_amount), axis=1)
subset
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   index                                     course_cuisine       course  \
# 0     0  {'cuisine': ['Chinese', 'Asian'], 'course': ['...  Main Dishes
# 1     1  {'cuisine': ['Chinese', 'Japanese', 'Asian'], ...  Main Dishes
# 2     2  {'cuisine': ['Chinese', 'Asian'], 'course': ['...  Main Dishes
# 3     3  {'cuisine': ['Chinese'], 'course': ['Main Dish...  Main Dishes
# 4     4  {'cuisine': ['Chinese', 'Thai', 'Asian'], 'cou...  Main Dishes
#
#    cuisine                                             flavor  \
# 0  Chinese  {'sweet': 0.16666666666666666, 'meaty': 0.1666...
# 1  Chinese  {'sweet': 0.16666666666666666, 'meaty': 0.1666...
# 2  Chinese  {'sweet': 0.16666666666666666, 'meaty': 0.3333...
# 3  Chinese                                                NaN
# 4  Chinese  {'sweet': 0.16666666666666666, 'meaty': 0.1666...
#
#                                                 id  \
# 0                     Easy-Noodle-Stir-Fry-1170602
# 1          Asian-Style-Scallops-I-Adore-Food-55293
# 2  Spicy-Garlic-and-Pepper-Shrimp-Stir-Fry-1192554
# 3                    Easy-Chicken-Teriyaki-1172111
# 4             Garlic-Ginger-Shrimp-Stir-fry-758551
#
#                                          small_image rating  \
# 0  {'90': 'http://lh3.googleusercontent.com/WdmaP...      4
# 1  {'90': 'http://lh3.ggpht.com/Vnl0Mbwo4IdWOqcYE...      5
# 2  {'90': 'http://lh3.googleusercontent.com/uudxX...      4
# 3  {'90': 'http://lh3.googleusercontent.com/RU_qv...      4
# 4  {'90': 'http://lh5.ggpht.com/lqkAt8R6fKG_c5_-W...      4
#
#                                       name  \
# 0                     Easy Noodle Stir Fry
# 1                     Asian Style Scallops
# 2  Spicy Garlic and Pepper Shrimp Stir-Fry
# 3                    Easy Chicken Teriyaki
# 4            Garlic Ginger Shrimp Stir fry
#
#                                  another_small_image             provider  \
# 0  ['http://lh3.googleusercontent.com/m1j40nD8FRF...  Heavenly Homemakers
# 1  ['http://lh4.ggpht.com/6VeH1YQdnV-ZqBsuEayBreJ...        I Adore Food!
# 2  ['http://lh3.googleusercontent.com/DgaFU94SZe8...   Fit and Fab Living
# 3  ['http://lh3.googleusercontent.com/Ev7ueRz0B7k...    Savory Sweet Life
# 4  ['http://lh5.ggpht.com/k5SotrjMX2iwPjZRs4cikps...       Steamy Kitchen
#
#    time                                          big_image  \
# 0  1500  http://lh3.googleusercontent.com/WdmaPnB7Bvcxb...
# 1   600  http://lh3.ggpht.com/Vnl0Mbwo4IdWOqcYET5awaFFr...
# 2  1800  http://lh3.googleusercontent.com/uudxX6XStM9J8...
# 3   900  http://lh3.googleusercontent.com/RU_qv8V8sltoT...
# 4   900  http://lh5.ggpht.com/lqkAt8R6fKG_c5_-Wr-qm40F3...
#
#                                    ingredient_amount  serving_number  \
# 0  ['2-4 cups fresh or frozen veggies of your cho...               4
# 1  ['10 big Scallops', '4 Tablespoon of soy sauce...               4
# 2  ['2 1/2 tbsp. vegetable oil', '1/4 cup water',...               4
# 3  ['soy sauce', 'sugar', 'sesame oil', 'chopped ...               4
# 4  ['2 tablespoons oyster sauce', '1 tablespoons ...               4
#
#                                            nutrition  hie_label  dbscan_label  \
# 0  [{'attribute': 'FAT_KCAL', 'description': None...          2             0
# 1  [{'attribute': 'FAT_KCAL', 'description': None...          2             0
# 2  [{'attribute': 'FAT_KCAL', 'description': None...          2             0
# 3  [{'attribute': 'FAT_KCAL', 'description': None...          2             0
# 4  [{'attribute': 'FAT_KCAL', 'description': None...          2             0
#
#                                        processed_ing
# 0  powder+corn+squash+olive+sea+choice+frozen+soy...
# 1  freshly+soy+oil+herbs+worcestershire+presentat...
# 2  onion+flakes+cabbage+shrimp+soy+shredded+water...
# 3  thighs+soy+oil+boneless+chicken+sauce+vinegar+...
# 4  handful+onion+green+tails+oyster+left+cloves+s...
